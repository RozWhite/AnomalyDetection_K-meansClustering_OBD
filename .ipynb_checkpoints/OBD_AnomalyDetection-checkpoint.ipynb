# %% [markdown]
# # Anomaly Detection with K-means Clustering
# Time Series Anomaly Detection using K-means Clustering for OBD (On Board Diagnostics) dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #  Importing the Data

# %%
#https://www.kaggle.com/datasets/vbandaru/data-from-obd-on-board-diagnostics
obd=pd.read_csv('OBD.csv')

# %%
obd
# Out:
#                           GPS Time  Device Time   Longitude   Latitude  \
# 0     Thu Nov 02 15:44:24 CDT 2017      44:25.1  -97.662474  30.483089
# 1     Thu Nov 02 15:44:25 CDT 2017      44:26.1  -97.662476  30.483068
# 2     Thu Nov 02 15:44:26 CDT 2017      44:27.1  -97.662478  30.483006
# 3     Thu Nov 02 15:44:27 CDT 2017      44:28.1  -97.662546  30.482689
# 4     Thu Nov 02 15:44:27 CDT 2017      44:29.1  -97.662546  30.482689
# ...                            ...          ...         ...        ...
# 1351  Thu Nov 02 16:06:56 CDT 2017      06:56.1  -97.768033  30.574161
# 1352  Thu Nov 02 16:06:57 CDT 2017      06:57.1  -97.768063  30.574162
# 1353  Thu Nov 02 16:06:58 CDT 2017      06:58.1  -97.768094  30.574162
# 1354  Thu Nov 02 16:06:58 CDT 2017      06:59.1  -97.768094  30.574162
# 1355  Thu Nov 02 16:06:58 CDT 2017      07:00.1  -97.768094  30.574162
#
#       GPS Speed (Meters/second)   Horizontal Dilution of Precision   Altitude  \
# 0                      2.795157                                 93        250
# 1                      0.000000                                 98        255
# 2                      0.000000                                105        247
# 3                      0.000000                                101        225
# 4                      0.000000                                101        225
# ...                         ...                                ...        ...
# 1351                   2.946795                                 21        272
# 1352                   2.936818                                 22        272
# 1353                   2.926175                                 25        272
# 1354                   2.926175                                 25        272
# 1355                   2.926175                                 25        272
#
#        Bearing      G(x)      G(y)       G(z)   G(calibrated)  \
# 0        211.6  0.350434  9.163701  -2.947818        0.000910
# 1          0.0 -6.745979  4.394452  -4.039574       -0.062790
# 2          0.0 -0.923281  7.736757   3.870868       -0.094130
# 3          0.0 -4.792311  2.172633  16.387754        0.773513
# 4          0.0 -0.061368  7.190879   6.686450        0.038575
# ...        ...       ...       ...        ...             ...
# 1351     271.7  1.591742  5.998988   7.163911       -0.014786
# 1352     271.7  0.500446  5.223496   8.457009        0.033547
# 1353     271.6 -0.667925  5.855566   7.844094        0.019143
# 1354     271.6  0.481292  5.453340   8.064361        0.012580
# 1355     271.6 -1.817141  5.865143   7.681288        0.021429
#
#       Engine Coolant Temperature(°C)  Engine RPM(rpm)  \
# 0                                 56          2623.25
# 1                                 56          3169.50
# 2                                 56          2587.50
# 3                                 57          2753.00
# 4                                 57          2957.00
# ...                              ...              ...
# 1351                              89           718.75
# 1352                              89           798.25
# 1353                              89           799.00
# 1354                              89           784.25
# 1355                              89           644.50
#
#       Intake Air Temperature(°C)  Engine Load(%)  Mass Air Flow Rate(g/s)  \
# 0                             30       92.549019                33.759998
# 1                             30       90.980392                37.200001
# 2                             30       98.431374                35.180000
# 3                             30       98.039215                38.040001
# 4                             30       96.862747                39.349998
# ...                          ...             ...                      ...
# 1351                          32       47.843140                 3.920000
# 1352                          32       46.666668                 3.750000
# 1353                          32       37.647060                 2.260000
# 1354                          32       33.333332                 2.320000
# 1355                          33       36.470589                 2.340000
#
#       Throttle Position(Manifold)(%)
# 0                          32.549019
# 1                          32.549019
# 2                          37.647060
# 3                          39.215687
# 4                          38.823528
# ...                              ...
# 1351                       16.470589
# 1352                       16.470589
# 1353                       15.294118
# 1354                       15.294118
# 1355                       15.294118
#
# [1356 rows x 18 columns]

# %%
#obd = obd[obd['GPS Speed (Meters/second)']!=0.0]

# %% [markdown]
# # EDA

# %%
allcolumns = obd.columns

unique_counts = []
missing_counts = []

for col in allcolumns:
    unique_counts.append(round((obd[col].nunique() * 100)/obd.shape[0],3))
    missing_counts.append(round((obd[col].isna().sum() * 100)/obd.shape[0],3))
    

data = {'Feature': allcolumns, '% of unique values': unique_counts, '% of Missing values': missing_counts}
obd_counts  = pd.DataFrame.from_dict(data)

obd_counts.sort_values(by='% of Missing values', ascending=False)
# Out:
#                               Feature  % of unique values  % of Missing values
# 0                            GPS Time              66.740                  0.0
# 1                         Device Time             100.000                  0.0
# 16            Mass Air Flow Rate(g/s)              53.024                  0.0
# 15                     Engine Load(%)              15.413                  0.0
# 14         Intake Air Temperature(°C)               0.516                  0.0
# 13                    Engine RPM(rpm)              70.723                  0.0
# 12     Engine Coolant Temperature(°C)               2.581                  0.0
# 11                      G(calibrated)             100.000                  0.0
# 10                               G(z)              91.593                  0.0
# 9                                G(y)              89.528                  0.0
# 8                                G(x)              86.504                  0.0
# 7                             Bearing              38.938                  0.0
# 6                            Altitude               9.956                  0.0
# 5    Horizontal Dilution of Precision               8.112                  0.0
# 4           GPS Speed (Meters/second)              60.767                  0.0
# 3                            Latitude              64.897                  0.0
# 2                           Longitude              65.634                  0.0
# 17     Throttle Position(Manifold)(%)               7.153                  0.0

# %%
obd.dtypes
# Out:
# GPS Time                              object
#  Device Time                          object
#  Longitude                           float64
#  Latitude                            float64
# GPS Speed (Meters/second)            float64
#  Horizontal Dilution of Precision      int64
#  Altitude                              int64
#  Bearing                             float64
#  G(x)                                float64
#  G(y)                                float64
#  G(z)                                float64
#  G(calibrated)                       float64
# Engine Coolant Temperature(°C)         int64
# Engine RPM(rpm)                      float64
# Intake Air Temperature(°C)             int64
# Engine Load(%)                       float64
# Mass Air Flow Rate(g/s)              float64
# Throttle Position(Manifold)(%)       float64
# dtype: object

# %% [markdown]
# ### Correlation

# %%
n= (obd.dtypes != 'object')
numeric_features= list(n[n].index)
print("Numeric_features:")
print(numeric_features)
# Out:
# Numeric_features:
# [' Longitude', ' Latitude', 'GPS Speed (Meters/second)', ' Horizontal Dilution of Precision', ' Altitude', ' Bearing', ' G(x)', ' G(y)', ' G(z)', ' G(calibrated)', 'Engine Coolant Temperature(°C)', 'Engine RPM(rpm)', 'Intake Air Temperature(°C)', 'Engine Load(%)', 'Mass Air Flow Rate(g/s)', 'Throttle Position(Manifold)(%)']

# %%
numeric_features =obd[numeric_features ]

# %%
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor =numeric_features.corr()
sb.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %% [markdown]
# 'Engine Load(%)' ,'Mass Air Flow Rate(g/s)' and 'Throttle Position(Manifold)(%)' are strongly corrolated.

# %% [markdown]
# ### Set time index

# %%
import datetime as dt
from datetime import timedelta

# %%
obd["GPS Time"]=pd.to_datetime(obd["GPS Time"])
# Out:
# C:\Users\Rozita\anaconda3\envs\tf\lib\site-packages\dateutil\parser\_parser.py:1207: UnknownTimezoneWarning: tzname CDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "

# %%
obd['dates'] = pd.to_datetime(obd["GPS Time"]).dt.date
obd['time'] = pd.to_datetime(obd["GPS Time"]).dt.time

# %%
print("Start time is: ", obd['time'].min())
print("End time is: ", obd['time'].max())
# Out:
# Start time is:  15:44:24
# End time is:  16:06:58

# %%
# set time index
obd= obd.set_index('time')

# %% [markdown]
#  # Kmean Clustering Anomaly Detection

# %%
data = obd[[' Altitude',' Bearing',' Longitude', ' G(x)',' Horizontal Dilution of Precision',' Latitude',
 'Engine Coolant Temperature(°C)','Engine RPM(rpm)','Intake Air Temperature(°C)','Mass Air Flow Rate(g/s)','Throttle Position(Manifold)(%)','Engine Load(%)']]



n_cluster = range(1, 20)
kmeans = [KMeans(n_clusters=i).fit(data) for i in n_cluster]
scores = [kmeans[i].score(data) for i in range(len(kmeans))]
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(n_cluster, scores)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show();

# %% [markdown]
# From the above elbow curve, we see that the graph levels off after 5 clusters, so We set n_clusters=5

# %%
km= KMeans(n_clusters = 5)
data['cluster'] = km.fit_predict(data)
# Out:
# C:\Users\Rozita\AppData\Local\Temp\ipykernel_15220\1135390164.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['cluster'] = km.fit_predict(data)

# %%
data['cluster'].value_counts()
# Out:
# 0    397
# 2    357
# 3    314
# 1    258
# 4     30
# Name: cluster, dtype: int64

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2).fit(data)
data2D = pca.transform(data)

# %%
label=km.labels_
u_labels = np.unique(label)

# %%
plt.figure(figsize=(10, 8))
for i in u_labels:
    plt.scatter(data2D[label == i , 0] ,data2D[label == i , 1] , label = i)
plt.legend()
plt.show()

# %%
#find the minor label
minor_label = data['cluster'].value_counts().idxmin()
data['cluster_flag'] = (data['cluster'] == minor_label)
# Out:
# C:\Users\Rozita\AppData\Local\Temp\ipykernel_15220\3588454902.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['cluster_flag'] = (data['cluster'] == minor_label)

# %%
#Label Encoding on the minor label 
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
data['anomaly'] = labelencoder.fit_transform(data['cluster_flag'])
# Out:
# C:\Users\Rozita\AppData\Local\Temp\ipykernel_15220\3367866105.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['anomaly'] = labelencoder.fit_transform(data['cluster_flag'])

# %%
data
# Out:
#            Altitude   Bearing   Longitude      G(x)  \
# time
# 15:44:24        250     211.6  -97.662474  0.350434
# 15:44:25        255       0.0  -97.662476 -6.745979
# 15:44:26        247       0.0  -97.662478 -0.923281
# 15:44:27        225       0.0  -97.662546 -4.792311
# 15:44:27        225       0.0  -97.662546 -0.061368
# ...             ...       ...         ...       ...
# 16:06:56        272     271.7  -97.768033  1.591742
# 16:06:57        272     271.7  -97.768063  0.500446
# 16:06:58        272     271.6  -97.768094 -0.667925
# 16:06:58        272     271.6  -97.768094  0.481292
# 16:06:58        272     271.6  -97.768094 -1.817141
#
#            Horizontal Dilution of Precision   Latitude  \
# time
# 15:44:24                                 93  30.483089
# 15:44:25                                 98  30.483068
# 15:44:26                                105  30.483006
# 15:44:27                                101  30.482689
# 15:44:27                                101  30.482689
# ...                                     ...        ...
# 16:06:56                                 21  30.574161
# 16:06:57                                 22  30.574162
# 16:06:58                                 25  30.574162
# 16:06:58                                 25  30.574162
# 16:06:58                                 25  30.574162
#
#           Engine Coolant Temperature(°C)  Engine RPM(rpm)  \
# time
# 15:44:24                              56          2623.25
# 15:44:25                              56          3169.50
# 15:44:26                              56          2587.50
# 15:44:27                              57          2753.00
# 15:44:27                              57          2957.00
# ...                                  ...              ...
# 16:06:56                              89           718.75
# 16:06:57                              89           798.25
# 16:06:58                              89           799.00
# 16:06:58                              89           784.25
# 16:06:58                              89           644.50
#
#           Intake Air Temperature(°C)  Mass Air Flow Rate(g/s)  \
# time
# 15:44:24                          30                33.759998
# 15:44:25                          30                37.200001
# 15:44:26                          30                35.180000
# 15:44:27                          30                38.040001
# 15:44:27                          30                39.349998
# ...                              ...                      ...
# 16:06:56                          32                 3.920000
# 16:06:57                          32                 3.750000
# 16:06:58                          32                 2.260000
# 16:06:58                          32                 2.320000
# 16:06:58                          33                 2.340000
#
#           Throttle Position(Manifold)(%)  Engine Load(%)  cluster  \
# time
# 15:44:24                       32.549019       92.549019        0
# 15:44:25                       32.549019       90.980392        4
# 15:44:26                       37.647060       98.431374        0
# 15:44:27                       39.215687       98.039215        0
# 15:44:27                       38.823528       96.862747        4
# ...                                  ...             ...      ...
# 16:06:56                       16.470589       47.843140        2
# 16:06:57                       16.470589       46.666668        2
# 16:06:58                       15.294118       37.647060        2
# 16:06:58                       15.294118       33.333332        2
# 16:06:58                       15.294118       36.470589        2
#
#           cluster_flag  anomaly
# time
# 15:44:24         False        0
# 15:44:25          True        1
# 15:44:26         False        0
# 15:44:27         False        0
# 15:44:27          True        1
# ...                ...      ...
# 16:06:56         False        0
# 16:06:57         False        0
# 16:06:58         False        0
# 16:06:58         False        0
# 16:06:58         False        0
#
# [1356 rows x 15 columns]

# %% [markdown]
# ### Plotting Anomaly detection for tempratures

# %%
data[['Engine Coolant Temperature(°C)','Intake Air Temperature(°C)','anomaly']].plot(subplots=True,figsize=(20,6))
plt.show()

# %% [markdown]
# ### Plotting Anomaly detection for Mass Air Flow Rate, Engine load and Intake Air Temperature(°C)

# %%
data[['Mass Air Flow Rate(g/s)','Engine Load(%)','Intake Air Temperature(°C)','anomaly']].plot(subplots=True,figsize=(20,6))
plt.show()

# %%
data[[' Altitude','Mass Air Flow Rate(g/s)','Throttle Position(Manifold)(%)','Engine Load(%)','Engine RPM(rpm)','Intake Air Temperature(°C)','anomaly']].plot(subplots=True,figsize=(20,12))
plt.show()
